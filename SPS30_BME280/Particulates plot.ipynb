# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import datetime

# %%
factor = 2
SMALL_SIZE = factor*8
MEDIUM_SIZE = factor*10
BIGGER_SIZE = factor*12
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %% [markdown]
# ### Plotting functions

# %%
def plot_simple(fname, all_PM=False):
    # get radiation data
    data = np.genfromtxt(fname, delimiter=',', invalid_raise=False)
    t = [datetime.datetime.fromtimestamp(x) for x in data[:,0]]
    
    if all_PM:
        plt.plot(t, data[:,1], label="PM1.0")
        plt.plot(t, data[:,2]-data[:,1], label="PM2.5 $-$ PM1.0")
        plt.plot(t, data[:,3]-data[:,2], label="PM4.0 $-$ PM2.5")
        plt.plot(t, data[:,4]-data[:,3], label="PM10.0 $-$ PM4.0")
        plt.legend(loc=(1.05,.25))
    else:
        plt.plot(t, data[:,2], label="PM2.5")
        plt.legend()
    
    plt.xticks(rotation=30)
    plt.xlabel("Date/time")
    plt.ylabel("PM [$\mu$g/m$^3$]")
    plt.grid()

# %% [markdown]
# ### Data

# %%
plot_simple("SPS30.log")
